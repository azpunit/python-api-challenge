# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup.
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Importing API key.
from api_keys import weather_api_key

# Incorporating citipy to determine city based on latitude and longitude.
from citipy import citipy

# Outputing File (CSV).
output_data_file = "/Users/azpunit/Desktop/python-api-challenge/output_data/cities.csv"

# Ranging of latitudes and longitudes.
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Listing for holding lat_lngs and cities.
lat_lngs = []
cities = []

# Creating a set of random lat and lng combinations.
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identifying nearest city for each lat, lng combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list.
    if city not in cities:
        cities.append(city)

# Printing the city count to confirm sufficient count.
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Saving api_keys information and query. 
url = "http://api.openweathermap.org/data/2.5/weather?"
temp_unit = "imperial"

query_url = f"{url}appid={weather_api_key}&units={temp_unit}&q="

# Printing the first part of our data retreival.
print("Beginning Data Retrieval")
print("-----------------------------")

# Preparing lists for holding our response.
lat = []
lng = []
temp_max = []
humidity = []
clouds = []
wind = []
dt = []
sys = []
name = []

# Looping through the cities and perform an API request on each of them. 
series = 0
set = 1
for city in cities:
    series = series+1
    if series == 50:
        series = 0
        set = set+1  
    response = requests.get(query_url + city).json()    
    try:
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        temp_max.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        clouds.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        dt.append(response['dt'])
        sys.append(response['sys']['country'])
        name.append(response['name'])
        print(f"Processing Record {series} of Set {set} | {city}")
    
    except KeyError:
        print("City not found. Skipping...")

# Printing the last part of our data retreival.
print("-----------------------------")
print("Data Retrieval Complete")     
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# City not found. Skipping...
# Processing Record 2 of Set 1 | ladario
# Processing Record 3 of Set 1 | ambulu
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | san quintin
# Processing Record 6 of Set 1 | pevek
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | presidencia roque saenz pena
# Processing Record 9 of Set 1 | jalu
# Processing Record 10 of Set 1 | novikovo
# Processing Record 11 of Set 1 | souillac
# Processing Record 12 of Set 1 | tecoanapa
# Processing Record 13 of Set 1 | betioky
# Processing Record 14 of Set 1 | waipawa
# Processing Record 15 of Set 1 | atuona
# Processing Record 16 of Set 1 | kruisfontein
# Processing Record 17 of Set 1 | portland
# Processing Record 18 of Set 1 | kapaa
# Processing Record 19 of Set 1 | laguna
# Processing Record 20 of Set 1 | tasiilaq
# Processing Record 21 of Set 1 | taltal
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | lucea
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | avarua
# City not found. Skipping...
# Processing Record 27 of Set 1 | maceio
# Processing Record 28 of Set 1 | oildale
# Processing Record 29 of Set 1 | talnakh
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | yar-sale
# Processing Record 32 of Set 1 | cherskiy
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | hobyo
# Processing Record 35 of Set 1 | vostok
# Processing Record 36 of Set 1 | port elizabeth
# Processing Record 37 of Set 1 | natal
# Processing Record 38 of Set 1 | busselton
# Processing Record 39 of Set 1 | trairi
# Processing Record 40 of Set 1 | owando
# Processing Record 41 of Set 1 | lavrentiya
# Processing Record 42 of Set 1 | esperance
# Processing Record 43 of Set 1 | nikolskoye
# Processing Record 44 of Set 1 | klyuchi
# Processing Record 45 of Set 1 | georgetown
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | dubbo
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | taketa
# Processing Record 0 of Set 2 | keflavik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record
# Processing Record 9 of Set 5 | saint anthony
# Processing Record 10 of Set 5 | vardo
# Processing Record 11 of Set 5 | itarema
# Processing Record 12 of Set 5 | dingle
# Processing Record 13 of Set 5 | samoded
# Processing Record 14 of Set 5 | beyneu
# Processing Record 15 of Set 5 | arraial do cabo
# Processing Record 16 of Set 5 | marystown
# Processing Record 17 of Set 5 | grindavik
# Processing Record 18 of Set 5 | axim
# Processing Record 19 of Set 5 | batagay-alyta
# Processing Record 20 of Set 5 | kungurtug
# Processing Record 21 of Set 5 | alofi
# Processing Record 22 of Set 5 | chara
# Processing Record 23 of Set 5 | padang
# Processing Record 24 of Set 5 | concordia
# Processing Record 25 of Set 5 | mionica
# Processing Record 26 of Set 5 | sao filipe
# Processing Record 27 of Set 5 | trofors
# Processing Record 28 of Set 5 | teguise
# Processing Record 29 of Set 5 | te anau
# Processing Record 30 of Set 5 | la ciotat
# Processing Record 31 of Set 5 | andilamena
# Processing Record 32 of Set 5 | shar
# Processing Record 33 of Set 5 | chuy
# Processing Record 34 of Set 5 | navirai
# Processing Record 35 of Set 5 | caluquembe
# Processing Record 36 of Set 5 | nyagan
# Processing Record 37 of Set 5 | mercedes
# Processing Record 38 of Set 5 | rawson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 5 | oneida
# Processing Record 42 of Set 5 | ilulissat
# Processing Record 43 of Set 5 | gravdal
# Processing Record 44 of Set 5 | victor harbor
# Processing Record 45 of Set 5 | yayva
# Processing Record 46 of Set 5 | huilong
# Processing Record 47 of Set 5 | umm lajj
# Processing Record 48 of Set 5 | ixtapa
# Processing Record 49 of Set 5 | san patricio
# Processing Record 0 of Set 6 | kulebaki
# Processing Record 1 of Set 6 | bathsheba
# Processing Record 2 of Set 6 | turinskaya sloboda
# Processing Record 3 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 6 | matagami
# Processing Record 5 of Set 6 | togur
# Processing Record 6 of Set 6 | port said
# City not found. Skipping...
# Processing Record 8 of Set 6 | hailar
# Processing Record 9 of Set 6 | pangnirtung
# Processing Record 10 of Set 6 | ostrovnoy
# Processing Record 11 of Set 6 | geraldton
# Processing Record 12 of Set 6 | saskylakh
# Processing Record 13 of Set 6 | biak
# Processing Record 14 of Set 6 | tilichiki
# Processing Record 15 of Set 6 | nouakchott
# Processing Record 16 of Set 6 | odweyne
# Processing Record 17 of Set 6 | jumla
# Processing Record 18 of Set 6 | santa cruz
# Processing Record 19 of Set 6 | mirabad
# Processing Record 20 of Set 6 | severo-kurilsk
# Processing Record 21 of Set 6 | camocim
# Processing Record 22 of Set 6 | port hawkesbury
# Processing Record 23 of Set 6 | govindgarh
# City not found. Skipping...
# Processing Record 25 of Set 6 | redding
# Processing Record 26 of Set 6 | asfi
# Processing Record 27 of Set 6 | broken hill
# Processing Record 28 of Set 6 | marrakesh
# Processing Record 29 of Set 6 | buala
# Processing Record 30 of Set 6 | teya
# Processing Record 31 of Set 6 | palu
# Processing Record 32 of Set 6 | katsuura
# Processing Record 33 of Set 6 | saint-georges
# City not found. Skipping...
# Processing Record 35 of Set 6 | dubai
# Processing Record 36 of Set 6 | port hedland
# Processing Record 37 of Set 6 | diego de almagro
# Processing Record 38 of Set 6 | poum
# Processing Record 39 of Set 6 | kirakira
# Processing Record 40 of Set 6 | nkowakowa
# Processing Record 41 of Set 6 | clinton
# Processing Record 42 of Set 6 | valparaiso
# Processing Record 43 of Set 6 | kasongo-lunda
# Processing Record 44 of Set 6 | sao joao da barra
# Processing Record 45 of Set 6 | pemba
# Processing Record 46 of Set 6 | kathmandu
# Processing Record 47 of Set 6 | bilma
# Processing Record 48 of Set 6 | machali
# Processing Record 49 of Set 6 | cabo san lucas
# Processing Record 0 of Set 7 | vao
# Processing Record 1 of Set 7 | cap malheureux
# Processing Record 2 of Set 7 | sawakin
# Processing Record 3 of Set 7 | da lat
# Processing Record 4 of Set 7 | valle de bravo
# Processing Record 5 of Set 7 | tazovskiy
# Processing Record 6 of Set 7 | koani
# Processing Record 7 of Set 7 | harper
# Processing Record 8 of Set 7 | hirara
# Processing Record 9 of Set 7 | kyren
# Processing Record 10 of Set 7 | faanui
# Processing Record 11 of Set 7 | kollam
# Processing Record 12 of Set 7 | effingham
# Processing Record 13 of Set 7 | rockhampton
# Processing Record 14 of Set 7 | mahebourg
# Processing Record 15 of Set 7 | payo
# Processing Record 16 of Set 7 | szaszvar
# Processing Record 17 of Set 7 | uyuni
# Processing Record 18 of Set 7 | envira
# City not found. Skipping...
# Processing Record 20 of Set 7 | svetlogorsk
# Processing Record 21 of Set 7 | mount gambier
# Processing Record 22 of Set 7 | sangueya
# Processing Record 23 of Set 7 | koungou
# Processing Record 24 of Set 7 | alcudia
# Processing Record 25 of Set 7 | bahia blanca
# City not found. Skipping...
# Processing Record 27 of Set 7 | manggar
# Processing Record 28 of Set 7 | pathri
# Processing Record 29 of Set 7 | sobolevo
# Processing Record 30 of Set 7 | kloulklubed
# Processing Record 31 of Set 7 | ambilobe
# Processing Record 32 of Set 7 | aklavik
# Processing Record 33 of Set 7 | kupino
# Processing Record 34 of Set 7 | statesboro
# Processing Record 35 of Set 7 | gat
# Processing Record 36 of Set 7 | hearst
# Processing Record 37 of Set 7 | touros
# Processing Record 38 of Set 7 | villazon
# Processing Record 39 of Set 7 | nishihara
# Processing Record 40 of Set 7 | cidreira
# Processing Record 41 of Set 7 | saint-pierre
# Processing Record 42 of Set 7 | wagar
# Processing Record 43 of Set 7 | peddapalli
# City not found. Skipping...
# Processing Record 45 of Set 7 | azle
# Processing Record 46 of Set 7 | bokoro
# Processing Record 47 of Set 7 | saint george
# Processing Record 48 of Set 7 | mizdah
# Processing Record 49 of Set 7 | port blair
# Processing Record 0 of Set 8 | jalesar
# Processing Record 1 of Set 8 | dargaville
# Processing Record 2 of Set 8 | ludvika
# Processing Record 3 of Set 8 | vilhena
# Processing Record 4 of Set 8 | tuatapere
# Processing Record 5 of Set 8 | mabay
# Processing Record 6 of Set 8 | sicuani
# Processing Record 7 of Set 8 | kudahuvadhoo
# Processing Record 8 of Set 8 | sungaipenuh
# Processing Record 9 of Set 8 | paciran
# Processing Record 10 of Set 8 | shingu
# Processing Record 11 of Set 8 | hasaki
# Processing Record 12 of Set 8 | clarence town
# Processing Record 13 of Set 8 | shimoda
# Processing Record 14 of Set 8 | mlonggo
# Processing Record 48 of Set 9 | mazagao
# Processing Record 49 of Set 9 | huron
# Processing Record 0 of Set 10 | sabha
# Processing Record 1 of Set 10 | bilibino
# Processing Record 2 of Set 10 | henties bay
# City not found. Skipping...
# Processing Record 4 of Set 10 | churapcha
# Processing Record 5 of Set 10 | necochea
# Processing Record 6 of Set 10 | isiro
# Processing Record 7 of Set 10 | barranca
# Processing Record 8 of Set 10 | christchurch
# Processing Record 9 of Set 10 | kavaratti
# City not found. Skipping...
# Processing Record 11 of Set 10 | tura
# Processing Record 12 of Set 10 | brandfort
# Processing Record 13 of Set 10 | orsha
# Processing Record 14 of Set 10 | bowen
# Processing Record 15 of Set 10 | maldonado
# Processing Record 16 of Set 10 | qeshm
# Processing Record 17 of Set 10 | sonta
# Processing Record 18 of Set 10 | scarborough
# Processing Record 19 of Set 10 | santa catarina de tepehuanes
# Processing Record 20 of Set 10 | le port
# Processing Record 21 of Set 10 | twin falls
# Processing Record 22 of Set 10 | komsomolskiy
# City not found. Skipping...
# Processing Record 24 of Set 10 | nguruka
# Processing Record 25 of Set 10 | kikwit
# Processing Record 26 of Set 10 | bend
# Processing Record 27 of Set 10 | tayshet
# Processing Record 28 of Set 10 | orhangazi
# City not found. Skipping...
# Processing Record 30 of Set 10 | inirida
# Processing Record 31 of Set 10 | sanandaj
# Processing Record 32 of Set 10 | smolenskoye
# City not found. Skipping...
# Processing Record 34 of Set 10 | akureyri
# Processing Record 35 of Set 10 | rondonopolis
# Processing Record 36 of Set 10 | mayo
# Processing Record 37 of Set 10 | majene
# Processing Record 38 of Set 10 | ilam
# Processing Record 39 of Set 10 | madanapalle
# Processing Record 40 of Set 10 | takoradi
# Processing Record 41 of Set 10 | kyshtovka
# Processing Record 42 of Set 10 | norman wells
# Processing Record 43 of Set 10 | novopokrovka
# Processing Record 44 of Set 10 | coahuayana
# Processing Record 45 of Set 10 | chicama
# Processing Record 46 of Set 10 | huaihua
# Processing Record 47 of Set 10 | mponela
# Processing Record 48 of Set 10 | muroto
# Processing Record 49 of Set 10 | karratha
# Processing Record 0 of Set 11 | leningradskiy
# Processing Record 1 of Set 11 | puerto escondido
# Processing Record 2 of Set 11 | khorixas
# Processing Record 3 of Set 11 | moron
# Processing Record 4 of Set 11 | wynyard
# Processing Record 5 of Set 11 | pemangkat
# Processing Record 6 of Set 11 | prince albert
# Processing Record 7 of Set 11 | fredericksburg
# Processing Record 8 of Set 11 | marsh harbour
# Processing Record 9 of Set 11 | martapura
# Processing Record 10 of Set 11 | lewistown
# Processing Record 11 of Set 11 | yinchuan
# Processing Record 12 of Set 11 | sandwick
# Processing Record 13 of Set 11 | cayenne
# Processing Record 14 of Set 11 | sioux lookout
# Processing Record 15 of Set 11 | kasama
# Processing Record 16 of Set 11 | adrar
# Processing Record 17 of Set 11 | yumen
# Processing Record 18 of Set 11 | mahon
# Processing Record 19 of Set 11 | vila franca do campo
# Processing Record 20 of Set 11 | whyalla
# Processing Record 21 of Set 11 | evanston
# Processing Record 22 of Set 11 | hindoria
# Processing Record 23 of Set 11 | kui buri
# Processing Record 24 of Set 11 | gamba
# Processing Record 25 of Set 11 | conceicao do araguaia
# Processing Record 26 of Set 11 | sao gabriel da cachoeira
# Processing Record 27 of Set 11 | mao
# City not found. Skipping...
# Processing Record 29 of Set 11 | pachino
# Processing Record 30 of Set 11 | thunder bay
# Processing Record 31 of Set 11 | itapuranga
# Processing Record 32 of Set 11 | nikolayevka
# Processing Record 33 of Set 11 | port moresby
# Processing Record 34 of Set 11 | praya
# City not found. Skipping...
# Processing Record 36 of Set 11 | tiarei
# Processing Record 37 of Set 11 | mongo
# Processing Record 38 of Set 11 | pierre
# Processing Record 39 of Set 11 | constitucion
# Processing Record 40 of Set 11 | black river
# Processing Record 41 of Set 11 | ketchikan
# Processing Record 42 of Set 11 | talara
# Processing Record 43 of Set 11 | flinders
# City not found. Skipping...
# Processing Record 45 of Set 11 | jablah
# Processing Record 46 of Set 11 | santa cruz do rio pardo
# Processing Record 47 of Set 11 | praia
# Processing Record 48 of Set 11 | bandarbeyla
# Processing Record 49 of Set 11 | meulaboh
# Processing Record 0 of Set 12 | acara
# Processing Record 1 of Set 12 | boa vista
# Processing Record 2 of Set 12 | ottawa
# Processing Record 3 of Set 12 | san luis potosi
# Processing Record 4 of Set 12 | hualmay
# Processing Record 5 of Set 12 | magadan
# Processing Record 6 of Set 12 | sindou
# Processing Record 7 of Set 12 | longonjo
# Processing Record 8 of Set 12 | rio brilhante
# Processing Record 9 of Set 12 | vigeland
# City not found. Skipping...
# Processing Record 11 of Set 12 | rio gallegos
# Processing Record 12 of Set 12 | nanga eboko
# Processing Record 13 of Set 12 | valdivia
# Processing Record 14 of Set 12 | sambava
# Processing Record 15 of Set 12 | shihezi
# Processing Record 16 of Set 12 | xuanhua
# Processing Record 17 of Set 12 | stokmarknes
# City not found. Skipping...
# Processing Record 19 of Set 12 | shiraoi
# Processing Record 20 of Set 12 | saint-alexandre
# Processing Record 21 of Set 12 | bereda
# Processing Record 22 of Set 12 | porto walter
# Processing Record 23 of Set 12 | grand gaube
# Processing Record 24 of Set 12 | aswan
# Processing Record 25 of Set 12 | davila
# Processing Record 26 of Set 12 | marzuq
# Processing Record 27 of Set 12 | sisimiut
# Processing Record 28 of Set 12 | xiaoweizhai
# Processing Record 29 of Set 12 | mount isa
# Processing Record 30 of Set 12 | high level
# Processing Record 31 of Set 12 | srednekolymsk
# Processing Record 32 of Set 12 | lindi
# Processing Record 33 of Set 12 | mogadishu
# Processing Record 34 of Set 12 | singaparna
# Processing Record 35 of Set 12 | waingapu
# City not found. Skipping...
# Processing Record 37 of Set 12 | katherine
# Processing Record 38 of Set 12 | inzer
# Processing Record 39 of Set 12 | kieta
# Processing Record 40 of Set 12 | palmer
# Processing Record 41 of Set 12 | shamkhal
# Processing Record 42 of Set 12 | juneau
# Processing Record 43 of Set 12 | seoul
# Processing Record 44 of Set 12 | atbasar
# Processing Record 45 of Set 12 | leh
# Processing Record 46 of Set 12 | cairo
# Processing Record 47 of Set 12 | bangkalan
# Processing Record 48 of Set 12 | catalao
# Processing Record 49 of Set 12 | launceston
# Processing Record 0 of Set 13 | sitka
# Processing Record 1 of Set 13 | grafton
# Processing Record 2 of Set 13 | sault sainte marie
# Processing Record 3 of Set 13 | vidim
# Processing Record 4 of Set 13 | mwinilunga
# Processing Record 5 of Set 13 | deputatskiy
# Processing Record 6 of Set 13 | la serena
# Processing Record 7 of Set 13 | quatre cocos
# Processing Record 8 of Set 13 | karlstad
# Processing Record 9 of Set 13 | lumby
# Processing Record 10 of Set 13 | wamba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Creating a dataframe and counting its cells for each column.
raw_city_dataframe = pd.DataFrame({"City": name,
                                   "Lat": lat,
                                   "Lng": lng,
                                   "Max Temp": temp_max,
                                   "Humidity": humidity,
                                   "Cloudiness": clouds,
                                   "Wind Speed": wind,
                                   "Country": sys,
                                   "Date": dt
                                  })

raw_city_dataframe.count()
# Out:
# City          559
# Lat           559
# Lng           559
# Max Temp      559
# Humidity      559
# Cloudiness    559
# Wind Speed    559
# Country       559
# Date          559
# dtype: int64

# %%
# Displaying the head of the columns of the Dataframe previously created.
raw_city_dataframe.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ladário -19.00  -57.60     86.00        40          90        2.24
# 1       Ambulu  -8.35  113.61     68.77        86          97        3.06
# 2      Ushuaia -54.80  -68.30     32.00        94          90       16.11
# 3  San Quintín  30.48 -115.95     70.61        63           0       11.41
# 4        Pevek  69.70  170.31     46.24        68          94        8.72
#
#   Country        Date
# 0      BR  1595626238
# 1      ID  1595626238
# 2      AR  1595626232
# 3      MX  1595626238
# 4      RU  1595626238

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# Using the function "describe" on several column of our previous DataFrame to see what is the maximum humidity.
intermediary_city_dataframe = raw_city_dataframe[["Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Date"]]
intermediary_city_dataframe.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  559.000000  559.000000  559.000000  559.000000  559.000000  559.000000
# mean    18.092934   19.461753   68.432809   70.153846   48.177102    7.704508
# std     33.619964   89.661980   14.106849   19.582871   37.856015    5.065635
# min    -54.800000 -175.200000   32.000000    8.000000    0.000000    0.090000
# 25%    -10.535000  -59.835000   57.000000   57.000000    6.000000    3.570000
# 50%     19.250000   25.570000   70.610000   76.000000   42.000000    6.870000
# 75%     47.420000   98.695000   79.080000   85.000000   87.000000   10.490000
# max     77.480000  179.320000  104.990000  100.000000  100.000000   28.970000
#
#                Date
# count  5.590000e+02
# mean   1.595626e+09
# std    7.336705e+01
# min    1.595626e+09
# 25%    1.595626e+09
# 50%    1.595626e+09
# 75%    1.595626e+09
# max    1.595626e+09

# %%
# Getting the indices of cities that have humidity over 100%.
intermediary_city_dataframe_2 = raw_city_dataframe.loc[raw_city_dataframe["Humidity"] > 100]
intermediary_city_dataframe_2["Humidity"].index
# Out:
# Int64Index([], dtype='int64')

# %%
# Making a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = raw_city_dataframe.drop(raw_city_dataframe[raw_city_dataframe["Humidity"] > 100].index, inplace = False)
clean_city_data.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Ladário -19.00  -57.60     86.00        40          90        2.24
# 1       Ambulu  -8.35  113.61     68.77        86          97        3.06
# 2      Ushuaia -54.80  -68.30     32.00        94          90       16.11
# 3  San Quintín  30.48 -115.95     70.61        63           0       11.41
# 4        Pevek  69.70  170.31     46.24        68          94        8.72
#
#   Country        Date
# 0      BR  1595626238
# 1      ID  1595626238
# 2      AR  1595626232
# 3      MX  1595626238
# 4      RU  1595626238

# %%
# Extracting relevant fields from the data frame.
raw_formatter = raw_city_dataframe[["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"]]
intermediary_formatter = raw_formatter.reset_index()
final_formatter = intermediary_formatter.rename(columns={"index": "City_ID"})
final_city_dataframe = final_formatter.set_index("City_ID")

# Exporting the City_Data into a csv.
final_city_dataframe.to_csv("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/City_Data.csv")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Drawing a scatter plot of the city latitude vs the maximum temperature.
plt.grid(True)
plt.scatter(clean_city_data['Lat'], clean_city_data['Max Temp'], color="steelblue", alpha=0.85, edgecolors="black")

plt.title("City Latitude vs. Max Temperature (07/20/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.ylim(-17, 108)
plt.xlim(-61.2, 84.8)

plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig1.png")
plt.show()

# %%
# This scatter plot above shows the relationship between the city latitude and the max temperature. 
# We can say that the max temperature is at its highest for the latitudes between 20 and 40.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Drawing a scatter plot of the city latitude vs the humidity.
plt.grid(True)
plt.scatter(clean_city_data['Lat'], clean_city_data['Humidity'], color="steelblue", alpha=0.85, edgecolors="black")

plt.title("City Latitude vs. Humidity (07/20/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.xlim(-61.2, 84.8)

plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig2.png")
plt.show()

# %%
# This scatter plot above shows the relationship between the city latitude and the humidity. 
# We can say that the max humidity is of 100 percent and the lowest humidity, which is of approximately 5 percent, is located at latitude 22.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Drawing a scatter plot of the city latitude vs the cloudiness.
plt.grid(True)
plt.scatter(clean_city_data['Lat'], clean_city_data['Cloudiness'], color="steelblue", alpha=0.85, edgecolors="black")

plt.title("City Latitude vs. Cloudiness (07/20/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.xlim(-61.2, 84.8)

plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig3.png")
plt.show()

# %%
# This scatter plot above shows the relationship between the city latitude and the cloudiness. 
# We can say that the cloudiness is quite equally spread between latitutes going from -43 to 70, going from 0 to 100 percent.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Drawing a scatter plot of the city latitude vs the wind speed.
plt.grid(True)
plt.scatter(clean_city_data['Lat'], clean_city_data['Wind Speed'], color="steelblue", alpha=0.85, edgecolors="black")

plt.title("City Latitude vs. Wind Speed (07/20/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.ylim(-2, 49)
plt.xlim(-61.2, 84.8)

plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig4.png")
plt.show()

# %%
# This scatter plot above shows the relationship between the city latitude and the wind speed. 
# No matter what is the latitude, most values of the wind speed are comprised between 0 and 15 mph.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Creating a function to create Linear Regression plots.
def northern_regression_plots(x, y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regression_equation = x * slope + intercept
    regression_equation_plot = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x, regression_equation, "r-")
    plt.annotate(regression_equation_plot, (20, 40), fontsize=15, color="red")
    print(f"The r-squared is: {rvalue**2}")

def southern_regression_plots(x, y):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regression_equation = x * slope + intercept
    regression_equation_plot = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x, regression_equation, "r-")
    plt.annotate(regression_equation_plot, (-50, 20), fontsize=15, color="red")
    print(f"The r-squared is: {rvalue**2}")

# %%
# Creating Northern and Southern Hemisphere DataFrames.
columns = ["City", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Country", "Date"]

northern_hemisphere_dataframe = clean_city_data.loc[clean_city_data["Lat"] >= 0, columns]
southern_hemisphere_dataframe = clean_city_data.loc[clean_city_data["Lat"] < 0, columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Drawing a scatter plot with a regression line of the city latitude vs the maximum temperature in the northern hemisphere.
northern_latitude = northern_hemisphere_dataframe["Lat"]
northern_max_temp = northern_hemisphere_dataframe["Max Temp"]

plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.ylabel("Max Temp")
plt.xlabel("Latitude")

plt.ylim(-15, 107)

northern_regression_plots(northern_latitude, northern_max_temp)
plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig5.png")
# Out:
# The r-squared is: 0.42557084712684906

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Drawing a scatter plot with a regression line of the city latitude vs the maximum temperature in the southern hemisphere.
southern_latitude = southern_hemisphere_dataframe["Lat"]
southern_max_temp = southern_hemisphere_dataframe["Max Temp"]

plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")
plt.ylabel("Max Temp")
plt.xlabel("Latitude")

plt.ylim(12, 98)

southern_regression_plots(southern_latitude, southern_max_temp)
plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig6.png")
# Out:
# The r-squared is: 0.6126384300609032

# %%
# For my part, those scatter plots depicting the maximum temperature in function of the latitude for both the northern and the southern
# hemisphere really tell us that the maximum temperature reaches it's highest values as we get closer to latitude 0.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Drawing a scatter plot with a regression line of the city latitude vs the humidity in the northern hemisphere.
northern_latitude = northern_hemisphere_dataframe["Lat"]
northern_humidity = northern_hemisphere_dataframe["Humidity"]

plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.ylabel("Humidity")
plt.xlabel("Latitude")

plt.ylim(5, 103)

northern_regression_plots(northern_latitude, northern_humidity)
plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig7.png")
# Out:
# The r-squared is: 0.0010011337362503243

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Drawing a scatter plot with a regression line of the city latitude vs the humidity in the southern hemisphere.
southern_latitude = southern_hemisphere_dataframe["Lat"]
southern_humidity = southern_hemisphere_dataframe["Humidity"]

plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")
plt.ylabel("Humidity")
plt.xlabel("Latitude")

plt.ylim(13, 103)

southern_regression_plots(southern_latitude, southern_humidity)
plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig8.png")
# Out:
# The r-squared is: 0.001105438472665923

# %%
# Those scatter plots depicting the humidity in function of the latitude for both the northern and the southern
# hemisphere tell us that the humidity very slightly decreases as the latitude increases.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Drawing a scatter plot with a regression line of the city latitude vs the cloudiness in the northern hemisphere.
northern_latitude = northern_hemisphere_dataframe["Lat"]
northern_cloudiness = northern_hemisphere_dataframe["Cloudiness"]

plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")

plt.ylim(-3, 103)

northern_regression_plots(northern_latitude, northern_cloudiness)
plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig9.png")
# Out:
# The r-squared is: 0.006171606516105191

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Drawing a scatter plot with a regression line of the city latitude vs the cloudiness in the southern hemisphere.
southern_latitude = southern_hemisphere_dataframe["Lat"]
southern_cloudiness = southern_hemisphere_dataframe["Cloudiness"]

plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")

plt.ylim(-5, 104)

southern_regression_plots(southern_latitude, southern_cloudiness)
plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig10.png")
# Out:
# The r-squared is: 0.009528690100169365

# %%
# Those scatter plots depicting the cloudiness in function of the latitude for both the northern and the southern
# hemisphere tell us that the cloudiness very slightly increases as we get closer to latitude 0. 
# We can also say, given the particular shape of our plot, that most of the cloudiness highest values are concentrated around the latitude 0.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Drawing a scatter plot with a regression line of the city latitude vs the wind speed in the northern hemisphere.
northern_latitude = northern_hemisphere_dataframe["Lat"]
northern_wind_speed = northern_hemisphere_dataframe["Wind Speed"]

plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")

plt.ylim(-3, 49)

northern_regression_plots(northern_latitude, northern_wind_speed)
plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig11.png")
# Out:
# The r-squared is: 0.02499515426837141

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Drawing a scatter plot with a regression line of the city latitude vs the wind speed in the southern hemisphere.
southern_latitude = southern_hemisphere_dataframe["Lat"]
southern_wind_speed = southern_hemisphere_dataframe["Wind Speed"]

plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")

plt.ylim(-2, 27)

southern_regression_plots(southern_latitude, southern_wind_speed)
plt.savefig("/Users/azpunit/Desktop/python-api-challenge/WeatherPy/final_output_data/Fig12.png")
# Out:
# The r-squared is: 0.0014184979736562141

# %%
# Those scatter plots depicting the wind speed in function of the latitude for both the northern and the southern
# hemisphere tell us that the wind speed very slightly decreases as the latitude increases.
